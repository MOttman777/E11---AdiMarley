# %%
import time
import pandas as pd
import matplotlib.pyplot as plt 

data = r'C:\Users\12095\Documents\GitHub\E11---AdiMarley\sensor_data.csv'
rdata = pd.read_csv(data)
display(rdata)
# Out:
#            Time  PM10 std  PM25 std  PM 100 std  Temperature    Gas  \
# 0    1676506320         0         1           1    24.587617  19019
# 1    1676506320         0         1           1    24.610078   5859
# 2    1676506321         0         0           0    24.682344   7004
# 3    1676506322         0         0           0    24.746016   7901
# 4    1676506323         0         0           0    24.812227   8587
# ..          ...       ...       ...         ...          ...    ...
# 340  1676506617         0         1           1    25.132344  50149
# 341  1676506617         0         1           1    25.134492  50239
# 342  1676506618         0         1           2    25.125508  50179
# 343  1676506619         0         1           2    25.128047  50269
# 344  1676506620         0         1           2    25.131172  50299
#
#         Pressure  Altitude  Relative Humidity
# 0    1012.274902  8.121518          17.360945
# 1    1012.274609  8.123962          17.362126
# ...

# %%
#Temperature
plt.plot(rdata['Time'],rdata['Temperature'])
plt.xlabel('Time')
plt.ylabel('Temp')
plt.show()

# %%
#Gas
plt.plot(rdata['Time'],rdata['Gas'])
plt.xlabel('Time')
plt.ylabel('Gas')
plt.show()

# %%
#Pressure
plt.plot(rdata['Time'],rdata['Pressure'])
plt.xlabel('Time')
plt.ylabel('Pressure')
plt.show()

# %%
#Altitude
plt.plot(rdata['Time'],rdata['Altitude'])
plt.xlabel('Time')
plt.ylabel('Altitude')
plt.show()

# %%
#Relative humidity
plt.plot(rdata['Time'],rdata['Relative Humidity'])
plt.xlabel('Time')
plt.ylabel('Relative Humidity')
plt.show()

# %%
#PM10
plt.plot(rdata['Time'],rdata['PM10 std'])
plt.xlabel('Time')
plt.ylabel('PM10 std')
plt.show()

# %%
#PM25
plt.plot(rdata['Time'],rdata['PM25 std'])
plt.xlabel('Time')
plt.ylabel('PM25 std')
plt.show()

# %%
#PM100
plt.plot(rdata['Time'],rdata['PM 100 std'])
plt.xlabel('Time')
plt.ylabel('PM100 std')
plt.show()
